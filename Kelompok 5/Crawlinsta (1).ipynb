# %%
import requests
import time
import json
arr = []
end_cursor = '' # empty for the 1st page
tag = 'makassar' # your tag
page_count = 100 # desired number of pages
for i in range(0, page_count):
    url = "https://www.instagram.com/explore/tags/{0}/?__a=1&max_id={1}".format(tag, end_cursor)
    r = requests.get(url)
    data = json.loads(r.text)
    
    end_cursor = data['graphql']['hashtag']['edge_hashtag_to_media']['page_info']['end_cursor'] # value for the next page
    edges = data['graphql']['hashtag']['edge_hashtag_to_media']['edges'] # list with posts
    
    for item in edges:
       arr.append(item['node'])
    time.sleep(2) # insurence to not reach a time limit
#print(end_cursor) # save this to restart parsing with the next page
with open('instadataa.json', 'w') as outfile:
    json.dump(arr, outfile) # save to json

# %%
import json
import pandas as pd
with open('instadataa.json') as f:
   data = json.load(f)
print(pd.DataFrame(data))
# Out:
#         __typename                              accessibility_caption  \
# 0       GraphImage                    No photo description available.
# 1       GraphImage                    No photo description available.
# 2       GraphImage                    No photo description available.
# 3     GraphSidecar                    No photo description available.
# 4       GraphImage                           Image may contain: shoes
# 5     GraphSidecar                    No photo description available.
# 6       GraphImage                           Image may contain: shoes
# 7     GraphSidecar                 Image may contain: people standing
# 8     GraphSidecar                    No photo description available.
# 9       GraphImage                           Image may contain: shoes
# 10      GraphImage                    No photo description available.
# 11    GraphSidecar                 Image may contain: people standing
# 12      GraphImage                    No photo description available.
# 13      GraphImage                    No photo description available.
# 14      GraphImage                          Image may contain: shorts
# 15    GraphSidecar                    No photo description available.
# 16      GraphVideo                                                NaN
# 17      GraphVideo                                                NaN
# 18      GraphImage              Image may contain: one or more people
# 19      GraphVideo                                                NaN
# 20      GraphImage                    No photo description available.
# 21      GraphImage                           Image may contain: shoes
# 22      GraphImage                    No photo description available.
# 23    GraphSidecar                    No photo description available.
# 24      GraphImage  Image may contain: one or more people and peop...
# 25      GraphImage                    No photo description available.
# 26      GraphVideo                                                NaN
# 27      GraphImage                    No photo description available.
# 28    GraphSidecar                    No photo description available.
# 29      GraphImage     Image may contain: one or more people and text
# ...            ...                                                ...
# 6461    GraphImage                    No photo description available.
# 6462    GraphImage  Image may contain: one or more people, people ...
# 6463    GraphVideo                                                NaN
# 6464    GraphImage                            Image may contain: text
# 6465    GraphImage                            Image may contain: text
# 6466  GraphSidecar   Image may contain: one or more people and indoor
# 6467    GraphImage                            Image may contain: text
# 6468    GraphImage  Image may contain: one or more people, people ...
# 6469  GraphSidecar                    No photo description available.
# 6470    GraphImage                            Image may contain: text
# 6471    GraphImage              Image may contain: one or more people
# 6472    GraphImage                            Image may contain: text
# 6473    GraphImage                            Image may contain: text
# 6474    GraphImage              Image may contain: one or more people
# 6475    GraphImage              Image may contain: one or more people
# 6476    GraphVideo                                                NaN
# 6477    GraphImage                    No photo description available.
# 6478    GraphImage     Image may contain: one or more people and text
# 6479    GraphImage                    No photo description available.
# 6480    GraphImage                    No photo description available.
# 6481    GraphImage     Image may contain: one or more people and text
# 6482    GraphImage                            Image may contain: text
# 6483    GraphImage                           Image may contain: shoes
# 6484    GraphVideo                                                NaN
# 6485    GraphImage  Image may contain: one or more people and peop...
# 6486    GraphImage              Image may contain: one or more people
# 6487    GraphVideo                                                NaN
# 6488    GraphImage                           Image may contain: shoes
# 6489    GraphImage                           Image may contain: shoes
# 6490    GraphImage                        Image may contain: 9 people
#
#       comments_disabled                       dimensions  \
# 0                 False    {'height': 640, 'width': 640}
# 1                 False  {'height': 1080, 'width': 1080}
# 2                 False    {'height': 640, 'width': 640}
# 3                 False  {'height': 1080, 'width': 1080}
# 4                 False    {'height': 748, 'width': 750}
# 5                 False  {'height': 1080, 'width': 1080}
# 6                 False    {'height': 748, 'width': 750}
# 7                 False  {'height': 1080, 'width': 1080}
# 8                 False  {'height': 1080, 'width': 1080}
# 9                 False    {'height': 750, 'width': 750}
# 10                False  {'height': 1080, 'width': 1080}
# 11                False  {'height': 1080, 'width': 1080}
# 12                False  {'height': 1080, 'width': 1080}
# 13                False    {'height': 735, 'width': 750}
# 14                False  {'height': 1080, 'width': 1080}
# 15                False  {'height': 1080, 'width': 1080}
# 16                False    {'height': 640, 'width': 640}
# 17                False    {'height': 270, 'width': 480}
# 18                False  {'height': 1080, 'width': 1080}
# 19                False    {'height': 750, 'width': 750}
# 20                False  {'height': 1080, 'width': 1080}
# 21                False    {'height': 748, 'width': 750}
# 22                False  {'height': 1080, 'width': 1080}
# 23                False  {'height': 1080, 'width': 1080}
# 24                False  {'height': 1080, 'width': 1080}
# 25                False  {'height': 1080, 'width': 1080}
# 26                False    {'height': 270, 'width': 480}
# 27                False    {'height': 728, 'width': 750}
# 28                False  {'height': 1080, 'width': 1080}
# 29                False    {'height': 750, 'width': 750}
# ...                 ...                              ...
# 6461              False    {'height': 937, 'width': 750}
# 6462              False   {'height': 800, 'width': 1080}
# 6463              False    {'height': 270, 'width': 480}
# 6464              False  {'height': 1080, 'width': 1080}
# 6465              False  {'height': 1080, 'width': 1080}
# 6466              False  {'height': 1350, 'width': 1080}
# 6467              False  {'height': 1080, 'width': 1080}
# 6468              False  {'height': 1080, 'width': 1080}
# 6469              False  {'height': 1080, 'width': 1080}
# 6470              False  {'height': 1080, 'width': 1080}
# 6471              False   {'height': 607, 'width': 1080}
# 6472              False  {'height': 1080, 'width': 1080}
# 6473              False    {'height': 480, 'width': 480}
# 6474              False    {'height': 640, 'width': 640}
# 6475              False  {'height': 1080, 'width': 1080}
# 6476              False    {'height': 640, 'width': 640}
# 6477              False    {'height': 480, 'width': 480}
# 6478              False  {'height': 1179, 'width': 1080}
# 6479              False  {'height': 1062, 'width': 1080}
# 6480              False    {'height': 750, 'width': 750}
# 6481              False  {'height': 1180, 'width': 1080}
# 6482              False  {'height': 1080, 'width': 1080}
# 6483              False    {'height': 750, 'width': 750}
# 6484              False    {'height': 750, 'width': 750}
# 6485              False  {'height': 1080, 'width': 1080}
# 6486              False    {'height': 750, 'width': 750}
# 6487              False    {'height': 480, 'width': 480}
# 6488              False    {'height': 750, 'width': 750}
# 6489              False    {'height': 750, 'width': 750}
# 6490              False    {'height': 750, 'width': 750}
#
#                                             display_url    edge_liked_by  \
# 0     https://scontent-sin6-2.cdninstagram.com/vp/47...     {'count': 0}
# 1     https://scontent-sin6-2.cdninstagram.com/vp/20...     {'count': 0}
# 2     https://scontent-sin6-2.cdninstagram.com/vp/9c...     {'count': 0}
# 3     https://scontent-sin6-2.cdninstagram.com/vp/66...     {'count': 0}
# 4     https://scontent-sin6-2.cdninstagram.com/vp/25...     {'count': 0}
# 5     https://scontent-sin6-2.cdninstagram.com/vp/c6...     {'count': 0}
# 6     https://scontent-sin6-2.cdninstagram.com/vp/90...     {'count': 0}
# 7     https://scontent-sin6-2.cdninstagram.com/vp/8c...     {'count': 0}
# 8     https://scontent-sin6-2.cdninstagram.com/vp/0c...     {'count': 0}
# 9     https://scontent-sin6-2.cdninstagram.com/vp/d1...     {'count': 0}
# 10    https://scontent-sin6-2.cdninstagram.com/vp/ab...     {'count': 1}
# 11    https://scontent-sin6-2.cdninstagram.com/vp/b1...     {'count': 0}
# 12    https://scontent-sin6-2.cdninstagram.com/vp/b2...     {'count': 1}
# 13    https://scontent-sin6-2.cdninstagram.com/vp/b9...     {'count': 0}
# 14    https://scontent-sin6-2.cdninstagram.com/vp/84...     {'count': 0}
# 15    https://scontent-sin6-2.cdninstagram.com/vp/8b...     {'count': 1}
# 16    https://scontent-sin6-2.cdninstagram.com/vp/b9...     {'count': 2}
# 17    https://scontent-sin6-2.cdninstagram.com/vp/0c...     {'count': 2}
# 18    https://scontent-sin6-2.cdninstagram.com/vp/1d...     {'count': 0}
# 19    https://scontent-sin6-2.cdninstagram.com/vp/b5...     {'count': 1}
# 20    https://scontent-sin6-2.cdninstagram.com/vp/5b...     {'count': 2}
# 21    https://scontent-sin6-2.cdninstagram.com/vp/1a...     {'count': 0}
# 22    https://scontent-sin6-2.cdninstagram.com/vp/c6...     {'count': 1}
# 23    https://scontent-sin6-2.cdninstagram.com/vp/ea...     {'count': 1}
# 24    https://scontent-sin6-2.cdninstagram.com/vp/de...     {'count': 0}
# 25    https://scontent-sin6-2.cdninstagram.com/vp/16...     {'count': 1}
# 26    https://scontent-sin6-2.cdninstagram.com/vp/a3...     {'count': 1}
# 27    https://scontent-sin6-2.cdninstagram.com/vp/35...     {'count': 0}
# 28    https://scontent-sin6-2.cdninstagram.com/vp/ff...     {'count': 1}
# 29    https://scontent-sin6-2.cdninstagram.com/vp/52...     {'count': 2}
# ...                                                 ...              ...
# 6461  https://scontent-sin6-2.cdninstagram.com/vp/e9...     {'count': 7}
# 6462  https://scontent-sin6-2.cdninstagram.com/vp/16...     {'count': 1}
# 6463  https://scontent-sin6-2.cdninstagram.com/vp/ab...     {'count': 6}
# 6464  https://scontent-sin6-2.cdninstagram.com/vp/94...     {'count': 3}
# 6465  https://scontent-sin6-2.cdninstagram.com/vp/c5...     {'count': 3}
# 6466  https://scontent-sin6-2.cdninstagram.com/vp/a5...    {'count': 40}
# 6467  https://scontent-sin6-2.cdninstagram.com/vp/20...     {'count': 2}
# 6468  https://scontent-sin6-2.cdninstagram.com/vp/27...     {'count': 0}
# 6469  https://scontent-sin6-2.cdninstagram.com/vp/a6...     {'count': 5}
# 6470  https://scontent-sin6-2.cdninstagram.com/vp/f5...   {'count': 108}
# 6471  https://scontent-sin6-2.cdninstagram.com/vp/74...     {'count': 0}
# 6472  https://scontent-sin6-2.cdninstagram.com/vp/af...    {'count': 52}
# 6473  https://scontent-sin6-2.cdninstagram.com/vp/98...    {'count': 14}
# 6474  https://scontent-sin6-2.cdninstagram.com/vp/ee...     {'count': 7}
# 6475  https://scontent-sin6-2.cdninstagram.com/vp/23...     {'count': 4}
# 6476  https://scontent-sin6-2.cdninstagram.com/vp/9d...  {'count': 2307}
# 6477  https://scontent-sin6-2.cdninstagram.com/vp/5b...     {'count': 1}
# 6478  https://scontent-sin6-2.cdninstagram.com/vp/d9...     {'count': 4}
# 6479  https://scontent-sin6-2.cdninstagram.com/vp/49...     {'count': 3}
# 6480  https://scontent-sin6-2.cdninstagram.com/vp/d6...   {'count': 658}
# 6481  https://scontent-sin6-2.cdninstagram.com/vp/92...     {'count': 8}
# 6482  https://scontent-sin6-2.cdninstagram.com/vp/c3...    {'count': 92}
# 6483  https://scontent-sin6-2.cdninstagram.com/vp/70...    {'count': 12}
# 6484  https://scontent-sin6-2.cdninstagram.com/vp/80...   {'count': 231}
# 6485  https://scontent-sin6-2.cdninstagram.com/vp/88...     {'count': 4}
# 6486  https://scontent-sin6-2.cdninstagram.com/vp/69...     {'count': 3}
# 6487  https://scontent-sin6-2.cdninstagram.com/vp/9d...     {'count': 2}
# 6488  https://scontent-sin6-2.cdninstagram.com/vp/54...     {'count': 5}
# 6489  https://scontent-sin6-2.cdninstagram.com/vp/bd...    {'count': 13}
# 6490  https://scontent-sin6-2.cdninstagram.com/vp/58...    {'count': 51}
#
#      edge_media_preview_like  \
# 0               {'count': 0}
# 1               {'count': 0}
# 2               {'count': 0}
# 3               {'count': 0}
# 4               {'count': 0}
# 5               {'count': 0}
# 6               {'count': 0}
# 7               {'count': 0}
# 8               {'count': 0}
# 9               {'count': 0}
# 10              {'count': 1}
# 11              {'count': 0}
# 12              {'count': 1}
# 13              {'count': 0}
# 14              {'count': 0}
# 15              {'count': 1}
# 16              {'count': 2}
# 17              {'count': 2}
# 18              {'count': 0}
# 19              {'count': 1}
# 20              {'count': 2}
# 21              {'count': 0}
# 22              {'count': 1}
# 23              {'count': 1}
# 24              {'count': 0}
# 25              {'count': 1}
# 26              {'count': 1}
# 27              {'count': 0}
# 28              {'count': 1}
# 29              {'count': 2}
# ...                      ...
# 6461            {'count': 7}
# 6462            {'count': 1}
# 6463            {'count': 6}
# 6464            {'count': 3}
# 6465            {'count': 3}
# 6466           {'count': 40}
# 6467            {'count': 2}
# 6468            {'count': 0}
# 6469            {'count': 5}
# 6470          {'count': 108}
# 6471            {'count': 0}
# 6472           {'count': 52}
# 6473           {'count': 14}
# 6474            {'count': 7}
# 6475            {'count': 4}
# 6476         {'count': 2307}
# 6477            {'count': 1}
# 6478            {'count': 4}
# 6479            {'count': 3}
# 6480          {'count': 658}
# 6481            {'count': 8}
# 6482           {'count': 92}
# 6483           {'count': 12}
# 6484          {'count': 231}
# 6485            {'count': 4}
# 6486            {'count': 3}
# 6487            {'count': 2}
# 6488            {'count': 5}
# 6489           {'count': 13}
# 6490           {'count': 51}
#
#                                   edge_media_to_caption edge_media_to_comment  \
# 0     {'edges': [{'node': {'text': 'lokasi dan pengi...          {'count': 0}
# 1     {'edges': [{'node': {'text': 'Sweater keren \n...          {'count': 0}
# 2     {'edges': [{'node': {'text': 'lokasi dan pengi...          {'count': 0}
# 3     {'edges': [{'node': {'text': 'Sweater keren \n...          {'count': 0}
# 4     {'edges': [{'node': {'text': 'credit: @celebes...          {'count': 0}
# 5     {'edges': [{'node': {'text': 'Sweater keren \n...          {'count': 0}
# 6     {'edges': [{'node': {'text': 'credit: @celebes...          {'count': 0}
# 7     {'edges': [{'node': {'text': 'Sweater keren \n...          {'count': 0}
# 8     {'edges': [{'node': {'text': '#ready_tww2nd\nJ...          {'count': 0}
# 9     {'edges': [{'node': {'text': 'credit: @celebes...          {'count': 0}
# 10    {'edges': [{'node': {'text': 'shorts Surfing L...          {'count': 0}
# 11    {'edges': [{'node': {'text': 'Sweater keren \n...          {'count': 0}
# 12    {'edges': [{'node': {'text': 'shorts Surfing L...          {'count': 0}
# 13    {'edges': [{'node': {'text': 'Pernikahan adala...          {'count': 0}
# 14    {'edges': [{'node': {'text': 'shorts Surfing L...          {'count': 0}
# 15    {'edges': [{'node': {'text': 'Sweater keren \n...          {'count': 0}
# 16    {'edges': [{'node': {'text': 'Assalamualaikum ...          {'count': 0}
# 17    {'edges': [{'node': {'text': "We invite you al...          {'count': 0}
# 18    {'edges': [{'node': {'text': 'Warga di wilayah...          {'count': 0}
# 19    {'edges': [{'node': {'text': 'Pernikahan adala...          {'count': 0}
# 20    {'edges': [{'node': {'text': 'Sweater keren \n...          {'count': 0}
# 21    {'edges': [{'node': {'text': 'credit: @celebes...          {'count': 0}
# 22    {'edges': [{'node': {'text': 'Sweater keren \n...          {'count': 0}
# 23    {'edges': [{'node': {'text': '#ready_tww2nd\nJ...          {'count': 0}
# 24    {'edges': [{'node': {'text': 'Warga di wilayah...          {'count': 0}
# 25    {'edges': [{'node': {'text': "🤗 Voilà le modèl...          {'count': 0}
# 26    {'edges': [{'node': {'text': "Selamat ulang ta...          {'count': 0}
# 27    {'edges': [{'node': {'text': 'Pernikahan adala...          {'count': 0}
# 28    {'edges': [{'node': {'text': '#ready_tww2nd\nJ...          {'count': 0}
# 29    {'edges': [{'node': {'text': 'Semoga yang like...          {'count': 1}
# ...                                                 ...                   ...
# 6461  {'edges': [{'node': {'text': 'Info Order :\n➡ ...          {'count': 0}
# 6462  {'edges': [{'node': {'text': '🌟fix order silah...          {'count': 0}
# 6463  {'edges': [{'node': {'text': 'Sapi kurban pak ...          {'count': 0}
# 6464  {'edges': [{'node': {'text': 'TAG temen kamu y...          {'count': 0}
# 6465  {'edges': [{'node': {'text': 'TAG temen kamu y...          {'count': 0}
# 6466  {'edges': [{'node': {'text': 'Jika ingin di ke...          {'count': 0}
# 6467  {'edges': [{'node': {'text': 'TAG temen kamu y...          {'count': 0}
# 6468  {'edges': [{'node': {'text': '🌟fix order silah...          {'count': 0}
# 6469  {'edges': [{'node': {'text': 'ALEDA 78.000\n\n...          {'count': 0}
# 6470  {'edges': [{'node': {'text': 'PENUH PROMO SPEC...          {'count': 3}
# 6471  {'edges': [{'node': {'text': 'Situs Poker Onli...          {'count': 2}
# 6472  {'edges': [{'node': {'text': 'PENUH PROMO SPEC...          {'count': 1}
# 6473  {'edges': [{'node': {'text': 'Semoga yang like...          {'count': 0}
# 6474  {'edges': [{'node': {'text': 'ZIPER VANALOES\n...          {'count': 0}
# 6475  {'edges': [{'node': {'text': 'Aqilla set @195....          {'count': 0}
# 6476  {'edges': [{'node': {'text': '😍\nFollow @culul...         {'count': 29}
# 6477  {'edges': [{'node': {'text': 'Hari gini masih ...          {'count': 0}
# 6478  {'edges': [{'node': {'text': '#Repost @polda_s...          {'count': 0}
# 6479  {'edges': [{'node': {'text': '#pythonskin #pyt...          {'count': 0}
# 6480  {'edges': [{'node': {'text': 'JIKA BOLEH MEMIN...         {'count': 15}
# 6481  {'edges': [{'node': {'text': '#Repost @polda_s...          {'count': 0}
# 6482  {'edges': [{'node': {'text': 'Masa lalu biarla...          {'count': 2}
# 6483  {'edges': [{'node': {'text': 'Rp 450.000\nNike...          {'count': 0}
# 6484  {'edges': [{'node': {'text': 'Saat daerah lain...          {'count': 4}
# 6485  {'edges': [{'node': {'text': 'Tentunya bagi wa...          {'count': 1}
# 6486  {'edges': [{'node': {'text': 'Endorse by Teteh...          {'count': 0}
# 6487  {'edges': [{'node': {'text': 'Rasakan menjadi ...          {'count': 1}
# 6488  {'edges': [{'node': {'text': 'Rp 485.000\nNew ...          {'count': 0}
# 6489  {'edges': [{'node': {'text': 'Rp 455.000\nNew ...          {'count': 1}
# 6490  {'edges': [{'node': {'text': 'Jambu 14 🤗🤗🤗\n#k...          {'count': 0}
#
#                        id  is_video                  owner    shortcode  \
# 0     2108928214819516501     False   {'id': '1204107843'}  B1EawmtHbBV
# 1     2108928102578124076     False   {'id': '3959709913'}  B1Eau-LAfUs
# 2     2108928050419619928     False   {'id': '1204107843'}  B1EauNmHlhY
# 3     2108927921895800716     False   {'id': '3959709913'}  B1EasV5gH-M
# 4     2108927818581827689     False  {'id': '10151727646'}  B1Eaq1rgmBp
# 5     2108927737371586746     False   {'id': '3959709913'}  B1EapqDAHC6
# 6     2108927564272694856     False  {'id': '10151727646'}  B1EanI1gPZI
# 7     2108927494538249115     False   {'id': '3959709913'}  B1EamH5AcOb
# 8     2108927483045824520     False   {'id': '8912087544'}  B1Eal9MAUgI
# 9     2108927351218839442     False  {'id': '10151727646'}  B1EakCagR-S
# 10    2108927300721390718     False   {'id': '6741905698'}  B1EajTYnzR-
# 11    2108927229609141227     False   {'id': '3959709913'}  B1EaiRKAGPr
# 12    2108927199705813106     False   {'id': '6741905698'}  B1Eah1Tn9By
# 13    2108927156838007100     False  {'id': '13201013678'}  B1EahNYgQE8
# 14    2108927117035872773     False   {'id': '6741905698'}  B1EagoUHKIF
# 15    2108927076240361066     False   {'id': '3959709913'}  B1EagCUgoZq
# 16    2108925931809621218      True  {'id': '14958188810'}  B1EaPYfH0Ti
# 17    2108926651114408079      True   {'id': '1950764507'}  B1EaZ2ZB0iP
# 18    2108926976970980484     False   {'id': '2165012421'}  B1Eael3l_yE
# 19    2108926260053860811      True  {'id': '13201013678'}  B1EaUKMAOHL
# 20    2108926890852194894     False   {'id': '3959709913'}  B1EadVqg5pO
[{'src': 'https://scontent-sin6-2.cdninstagram...
# 7             1565623770  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 8             1565623768  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 9             1565623752  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 10            1565623746  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 11            1565623738  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 12            1565623734  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 13            1565623729  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 14            1565623725  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 15            1565623720  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 16            1565623717  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 17            1565623714  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 18            1565623708  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 19            1565623707  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 20            1565623698  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 21            1565623680  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 22            1565623679  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 23            1565623673  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 24            1565623652  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 25            1565623649  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 26            1565623622  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 27            1565623596  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 28            1565623589  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 29            1565623561  [{'src': 'https://scontent-sin6-2.cdninstagram...
# ...                  ...                                                ...
# 6461          1565570821  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6462          1565570805  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6463          1565570793  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6464          1565570774  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6465          1565570766  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6466          1565570762  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6467          1565570757  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6468          1565570752  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6469          1565570670  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6470          1565570637  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6471          1565570622  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6472          1565570611  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6473          1565570577  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6474          1565570567  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6475          1565570567  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6476          1565570553  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6477          1565570539  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6478          1565570529  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6479          1565570519  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6480          1565570467  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6481          1565570467  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6482          1565570452  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6483          1565570450  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6484          1565570443  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6485          1565570422  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6486          1565570409  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6487          1565570340  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6488          1565570290  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6489          1565570283  [{'src': 'https://scontent-sin6-2.cdninstagram...
# 6490          1509953102  [{'src': 'https://scontent-sin6-2.cdninstagram...
#
#                                           thumbnail_src  video_view_count
# 0     https://scontent-sin6-2.cdninstagram.com/vp/47...               NaN
# 1     https://scontent-sin6-2.cdninstagram.com/vp/ae...               NaN
# 2     https://scontent-sin6-2.cdninstagram.com/vp/9c...               NaN
# 3     https://scontent-sin6-2.cdninstagram.com/vp/6e...               NaN
# 4     https://scontent-sin6-2.cdninstagram.com/vp/bd...               NaN
# 5     https://scontent-sin6-2.cdninstagram.com/vp/4c...               NaN
# 6     https://scontent-sin6-2.cdninstagram.com/vp/41...               NaN
# 7     https://scontent-sin6-2.cdninstagram.com/vp/4d...               NaN
# 8     https://scontent-sin6-2.cdninstagram.com/vp/77...               NaN
# 9     https://scontent-sin6-2.cdninstagram.com/vp/e9...               NaN
# 10    https://scontent-sin6-2.cdninstagram.com/vp/ad...               NaN
# 11    https://scontent-sin6-2.cdninstagram.com/vp/cb...               NaN
# 12    https://scontent-sin6-2.cdninstagram.com/vp/96...               NaN
# 13    https://scontent-sin6-2.cdninstagram.com/vp/fc...               NaN
# 14    https://scontent-sin6-2.cdninstagram.com/vp/47...               NaN
# 15    https://scontent-sin6-2.cdninstagram.com/vp/37...               NaN
# 16    https://scontent-sin6-2.cdninstagram.com/vp/b9...               2.0
# 17    https://scontent-sin6-2.cdninstagram.com/vp/1d...               3.0
# 18    https://scontent-sin6-2.cdninstagram.com/vp/8d...               NaN
# 19    https://scontent-sin6-2.cdninstagram.com/vp/69...               1.0
# 20    https://scontent-sin6-2.cdninstagram.com/vp/3e...               NaN
# 21    https://scontent-sin6-2.cdninstagram.com/vp/74...               NaN
# 22    https://scontent-sin6-2.cdninstagram.com/vp/46...               NaN
# 23    https://scontent-sin6-2.cdninstagram.com/vp/29...               NaN
# 24    https://scontent-sin6-2.cdninstagram.com/vp/92...               NaN
# 25    https://scontent-sin6-2.cdninstagram.com/vp/61...               NaN
# 26    https://scontent-sin6-2.cdninstagram.com/vp/3b...               0.0
# 27    https://scontent-sin6-2.cdninstagram.com/vp/f3...               NaN
# 28    https://scontent-sin6-2.cdninstagram.com/vp/1b...               NaN
# 29    https://scontent-sin6-2.cdninstagram.com/vp/d6...               NaN
# ...                                                 ...               ...
# 6461  https://scontent-sin6-2.cdninstagram.com/vp/a5...               NaN
# 6462  https://scontent-sin6-2.cdninstagram.com/vp/ad...               NaN
# 6463  https://scontent-sin6-2.cdninstagram.com/vp/60...              47.0
# 6464  https://scontent-sin6-2.cdninstagram.com/vp/46...               NaN
# 6465  https://scontent-sin6-2.cdninstagram.com/vp/be...               NaN
# 6466  https://scontent-sin6-2.cdninstagram.com/vp/21...               NaN
# 6467  https://scontent-sin6-2.cdninstagram.com/vp/4b...               NaN
# 6468  https://scontent-sin6-2.cdninstagram.com/vp/32...               NaN
# 6469  https://scontent-sin6-2.cdninstagram.com/vp/61...               NaN
# 6470  https://scontent-sin6-2.cdninstagram.com/vp/2f...               NaN
# 6471  https://scontent-sin6-2.cdninstagram.com/vp/ab...               NaN
# 6472  https://scontent-sin6-2.cdninstagram.com/vp/88...               NaN
# 6473  https://scontent-sin6-2.cdninstagram.com/vp/98...               NaN
# 6474  https://scontent-sin6-2.cdninstagram.com/vp/ee...               NaN
# 6475  https://scontent-sin6-2.cdninstagram.com/vp/0b...               NaN
# 6476  https://scontent-sin6-2.cdninstagram.com/vp/9d...            9228.0
# 6477  https://scontent-sin6-2.cdninstagram.com/vp/5b...               NaN
# 6478  https://scontent-sin6-2.cdninstagram.com/vp/f8...               NaN
# 6479  https://scontent-sin6-2.cdninstagram.com/vp/1d...               NaN
# 6480  https://scontent-sin6-2.cdninstagram.com/vp/80...               NaN
# 6481  https://scontent-sin6-2.cdninstagram.com/vp/f5...               NaN
# 6482  https://scontent-sin6-2.cdninstagram.com/vp/c5...               NaN
# 6483  https://scontent-sin6-2.cdninstagram.com/vp/2b...               NaN
# 6484  https://scontent-sin6-2.cdninstagram.com/vp/d1...            1708.0
# 6485  https://scontent-sin6-2.cdninstagram.com/vp/12...               NaN
# 6486  https://scontent-sin6-2.cdninstagram.com/vp/0b...               NaN
# 6487  https://scontent-sin6-2.cdninstagram.com/vp/9d...              12.0
# 6488  https://scontent-sin6-2.cdninstagram.com/vp/4e...               NaN
# 6489  https://scontent-sin6-2.cdninstagram.com/vp/86...               NaN
# 6490  https://scontent-sin6-2.cdninstagram.com/vp/ae...               NaN
#
# [6491 rows x 17 columns]

# %%
import pandas as pd
from pandas.io.json import json_normalize
import datetime as dt

with open('instadataa.json') as f:
   data = json.load(f)
#print(pd.DataFrame(data))
#post_time = dt.fromtimestamp(data['taken_at_timestamp']).strftime('%Y-%m-%d %H:%M:%S')
data2 = pd.DataFrame(data, columns = ['owner','edge_media_to_caption','taken_at_timestamp'])
data2
# Out:
#                       owner  \
# 0      {'id': '1204107843'}
# 1      {'id': '3959709913'}
# 2      {'id': '1204107843'}
# 3      {'id': '3959709913'}
# 4     {'id': '10151727646'}
# 5      {'id': '3959709913'}
# 6     {'id': '10151727646'}
# 7      {'id': '3959709913'}
# 8      {'id': '8912087544'}
# 9     {'id': '10151727646'}
# 10     {'id': '6741905698'}
# 11     {'id': '3959709913'}
# 12     {'id': '6741905698'}
# 13    {'id': '13201013678'}
# 14     {'id': '6741905698'}
# 15     {'id': '3959709913'}
# 16    {'id': '14958188810'}
# 17     {'id': '1950764507'}
# 18     {'id': '2165012421'}
# 19    {'id': '13201013678'}
# 20     {'id': '3959709913'}
# 21    {'id': '10151727646'}
# 22     {'id': '3959709913'}
# 23     {'id': '8912087544'}
# 24     {'id': '2165012421'}
# 25     {'id': '4231683344'}
# 26     {'id': '3996473232'}
# 27    {'id': '13201013678'}
# 28     {'id': '8912087544'}
# 29     {'id': '7365985452'}
# ...                     ...
# 6461   {'id': '4712398518'}
# 6462    {'id': '932093253'}
# 6463  {'id': '15288371578'}
# 6464  {'id': '15146326912'}
# 6465  {'id': '15146326912'}
# 6466    {'id': '774983172'}
# 6467  {'id': '15146326912'}
# 6468    {'id': '932093253'}
# 6469   {'id': '8118732566'}
# 6470   {'id': '6677237590'}
# 6471   {'id': '7568723862'}
# 6472   {'id': '6677237590'}
# 6473  {'id': '16337626274'}
# 6474   {'id': '5385889970'}
# 6475   {'id': '4090890168'}
# 6476   {'id': '8511969942'}
# 6477  {'id': '10911902521'}
# 6478   {'id': '3422757940'}
# 6479   {'id': '1982665421'}
# 6480   {'id': '4555534657'}
# 6481   {'id': '3422757940'}
# 6482    {'id': '464689026'}
# 6483   {'id': '6010144820'}
# 6484   {'id': '8599526503'}
# 6485  {'id': '13211250343'}
# 6486   {'id': '7549692223'}
# 6487   {'id': '6979933143'}
# 6488   {'id': '6010144820'}
# 6489   {'id': '6010144820'}
# 6490   {'id': '2099325994'}
#
#                                   edge_media_to_caption  taken_at_timestamp
# 0     {'edges': [{'node': {'text': 'lokasi dan pengi...          1565623855
# 1     {'edges': [{'node': {'text': 'Sweater keren \n...          1565623842
# 2     {'edges': [{'node': {'text': 'lokasi dan pengi...          1565623836
# 3     {'edges': [{'node': {'text': 'Sweater keren \n...          1565623821
# 4     {'edges': [{'node': {'text': 'credit: @celebes...          1565623808
# 5     {'edges': [{'node': {'text': 'Sweater keren \n...          1565623799
# 6     {'edges': [{'node': {'text': 'credit: @celebes...          1565623778
# 7     {'edges': [{'node': {'text': 'Sweater keren \n...          1565623770
# 8     {'edges': [{'node': {'text': '#ready_tww2nd\nJ...          1565623768
# 9     {'edges': [{'node': {'text': 'credit: @celebes...          1565623752
# 10    {'edges': [{'node': {'text': 'shorts Surfing L...          1565623746
# 11    {'edges': [{'node': {'text': 'Sweater keren \n...          1565623738
# 12    {'edges': [{'node': {'text': 'shorts Surfing L...          1565623734
# 13    {'edges': [{'node': {'text': 'Pernikahan adala...          1565623729
# 14    {'edges': [{'node': {'text': 'shorts Surfing L...          1565623725
# 15    {'edges': [{'node': {'text': 'Sweater keren \n...          1565623720
# 16    {'edges': [{'node': {'text': 'Assalamualaikum ...          1565623717
# 17    {'edges': [{'node': {'text': "We invite you al...          1565623714
# 18    {'edges': [{'node': {'text': 'Warga di wilayah...          1565623708
# 19    {'edges': [{'node': {'text': 'Pernikahan adala...          1565623707
# 20    {'edges': [{'node': {'text': 'Sweater keren \n...          1565623698
# 21    {'edges': [{'node': {'text': 'credit: @celebes...          1565623680
# 22    {'edges': [{'node': {'text': 'Sweater keren \n...          1565623679
# 23    {'edges': [{'node': {'text': '#ready_tww2nd\nJ...          1565623673
# 24    {'edges': [{'node': {'text': 'Warga di wilayah...          1565623652
# 25    {'edges': [{'node': {'text': "🤗 Voilà le modèl...          1565623649
# 26    {'edges': [{'node': {'text': "Selamat ulang ta...          1565623622
# 27    {'edges': [{'node': {'text': 'Pernikahan adala...          1565623596
# 28    {'edges': [{'node': {'text': '#ready_tww2nd\nJ...          1565623589
# 29    {'edges': [{'node': {'text': 'Semoga yang like...          1565623561
# ...                                                 ...                 ...
# 6461  {'edges': [{'node': {'text': 'Info Order :\n➡ ...          1565570821
# 6462  {'edges': [{'node': {'text': '🌟fix order silah...          1565570805
# 6463  {'edges': [{'node': {'text': 'Sapi kurban pak ...          1565570793
# 6464  {'edges': [{'node': {'text': 'TAG temen kamu y...          1565570774
# 6465  {'edges': [{'node': {'text': 'TAG temen kamu y...          1565570766
# 6466  {'edges': [{'node': {'text': 'Jika ingin di ke...          1565570762
# 6467  {'edges': [{'node': {'text': 'TAG temen kamu y...          1565570757
# 6468  {'edges': [{'node': {'text': '🌟fix order silah...          1565570752
# 6469  {'edges': [{'node': {'text': 'ALEDA 78.000\n\n...          1565570670
# 6470  {'edges': [{'node': {'text': 'PENUH PROMO SPEC...          1565570637
# 6471  {'edges': [{'node': {'text': 'Situs Poker Onli...          1565570622
# 6472  {'edges': [{'node': {'text': 'PENUH PROMO SPEC...          1565570611
# 6473  {'edges': [{'node': {'text': 'Semoga yang like...          1565570577
# 6474  {'edges': [{'node': {'text': 'ZIPER VANALOES\n...          1565570567
# 6475  {'edges': [{'node': {'text': 'Aqilla set @195....          1565570567
# 6476  {'edges': [{'node': {'text': '😍\nFollow @culul...          1565570553
# 6477  {'edges': [{'node': {'text': 'Hari gini masih ...          1565570539
# 6478  {'edges': [{'node': {'text': '#Repost @polda_s...          1565570529
# 6479  {'edges': [{'node': {'text': '#pythonskin #pyt...          1565570519
# 6480  {'edges': [{'node': {'text': 'JIKA BOLEH MEMIN...          1565570467
# 6481  {'edges': [{'node': {'text': '#Repost @polda_s...          1565570467
# 6482  {'edges': [{'node': {'text': 'Masa lalu biarla...          1565570452
# 6483  {'edges': [{'node': {'text': 'Rp 450.000\nNike...          1565570450
# 6484  {'edges': [{'node': {'text': 'Saat daerah lain...          1565570443
# 6485  {'edges': [{'node': {'text': 'Tentunya bagi wa...          1565570422
# 6486  {'edges': [{'node': {'text': 'Endorse by Teteh...          1565570409
# 6487  {'edges': [{'node': {'text': 'Rasakan menjadi ...          1565570340
# 6488  {'edges': [{'node': {'text': 'Rp 485.000\nNew ...          1565570290
# 6489  {'edges': [{'node': {'text': 'Rp 455.000\nNew ...          1565570283
# 6490  {'edges': [{'node': {'text': 'Jambu 14 🤗🤗🤗\n#k...          1509953102
#
# [6491 rows x 3 columns]

# %%
data2['taken_at_timestamp'] = pd.to_datetime(data2['taken_at_timestamp'], unit='s')
data2 = pd.DataFrame(data2, columns = ['taken_at_timestamp'])
data2
# Out:
# 5    2019-08-12 15:29:59  15:29:59         15
# 4    2019-08-12 15:30:08  15:30:08         15
# 3    2019-08-12 15:30:21  15:30:21         15
# 2    2019-08-12 15:30:36  15:30:36         15
# 1    2019-08-12 15:30:42  15:30:42         15
# 0    2019-08-12 15:30:55  15:30:55         15
# 2204 2019-08-11 15:37:33  15:37:33         15
# 2203 2019-08-11 15:37:47  15:37:47         15
# 2202 2019-08-11 15:38:12  15:38:12         15
# 2201 2019-08-11 15:38:26  15:38:26         15
# 2200 2019-08-11 15:38:39  15:38:39         15
# 2525 2019-07-30 15:41:33  15:41:33         15
# 3501 2019-08-09 15:45:20  15:45:20         15
# 3500 2019-08-09 15:46:09  15:46:09         15
# 2066 2019-08-09 15:50:24  15:50:24         15
# 3359 2019-07-18 16:10:19  16:10:19         16
# 3358 2019-07-18 16:13:12  16:13:12         16
# 6290 2019-08-10 16:38:56  16:38:56         16
# 484  2019-08-02 18:09:52  18:09:52         18
# 3850 2019-07-09 18:31:47  18:31:47         18
# 2070 2019-08-01 18:40:26  18:40:26         18
# 2199 2019-08-11 20:27:53  20:27:53         20
# 2198 2019-08-11 20:35:35  20:35:35         20
# 5113 2019-07-31 21:27:53  21:27:53         21
# 5111 2019-08-08 21:31:44  21:31:44         21
# 5118 2019-07-14 22:11:58  22:11:58         22
# 2659 2019-08-11 22:26:07  22:26:07         22
# 2660 2019-08-08 22:29:48  22:29:48         22
# 2663 2019-08-01 22:31:22  22:31:22         22
# 2065 2019-08-11 23:58:20  23:58:20         23
#
# [6491 rows x 3 columns]

# %%
from collections import Counter
x=data2['time_hour']
Counter(x)
# Out:
# Counter({0: 161,
#          1: 393,
#          2: 554,
#          3: 388,
#          4: 555,
#          5: 472,
#          6: 280,
#          7: 350,
#          8: 419,
#          9: 477,
#          10: 423,
#          11: 496,
#          12: 491,
#          13: 548,
#          14: 285,
#          15: 184,
#          16: 3,
#          18: 3,
#          20: 2,
#          21: 2,
#          22: 4,
#          23: 1})

# %%
data_freq = Counter(x)
data_freq
# Out:
# Counter({0: 161,
#          1: 393,
#          2: 554,
#          3: 388,
#          4: 555,
#          5: 472,
#          6: 280,
#          7: 350,
#          8: 419,
#          9: 477,
#          10: 423,
#          11: 496,
#          12: 491,
#          13: 548,
#          14: 285,
#          15: 184,
#          16: 3,
#          18: 3,
#          20: 2,
#          21: 2,
#          22: 4,
#          23: 1})

# %%
data3 = pd.DataFrame(list(data_freq.items()), columns=['time_hour', 'Freq'])
data3
# Out:
#     time_hour  Freq
# 0           0   161
# 1           1   393
# 2           2   554
# 3           3   388
# 4           4   555
# 5           5   472
# 6           6   280
# 7           7   350
# 8           8   419
# 9           9   477
# 10         10   423
# 11         11   496
# 12         12   491
# 13         13   548
# 14         14   285
# 15         15   184
# 16         16     3
# 17         18     3
# 18         20     2
# 19         21     2
# 20         22     4
# 21         23     1

# %%
import matplotlib.pyplot as plt
plt.plot(data3['time_hour'],data3['Freq'],  color='blue', marker='o', linestyle='dashed',linewidth=2, markersize=5)

plt.title('Frequensi Hashtag tiap Jam')
plt.xlabel('Jam')
plt.ylabel('Frequensi')
plt.show()
